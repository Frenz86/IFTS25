# %% [markdown]
# # Stop Words
# Words like "a" and "the" appear so frequently that they don't require tagging as thoroughly as nouns, verbs and modifiers. We call these *stop words*, and they can be filtered from the text to be processed. spaCy holds a built-in list of some 326 English stop words.

# %%
# Perform standard imports:
import spacy
nlp = spacy.load('en_core_web_sm')

# %%
# Print the set of spaCy's default stop words (remember that sets are unordered):
print(nlp.Defaults.stop_words)
# Out:
# {'anyone', 'wherein', 'fifty', 'never', 'will', 'this', 'nothing', 'its', 'same', 'whether', 'during', 'full', 'nor', 'nevertheless', 'always', 'seeming', 'whole', 'empty', 'for', 'the', 'she', 'him', 'sometime', 'first', 'few', 'go', 'below', 'unless', 'behind', 'n’t', 'often', 'throughout', 'serious', 'and', 'however', '‘re', 'all', 'mostly', 'beforehand', 'each', 'thereupon', 'up', 'five', 'they', 'thereby', 'part', 'off', 'to', 'eight', 'eleven', 'side', 'has', 'us', 'except', '’re', 'many', 'toward', 'did', 'have', 'further', 'top', 'you', 'when', 'became', 'become', 'used', 'itself', 'through', 'towards', 'done', '‘s', 'anything', 'against', 'move', 'me', 'sixty', 'already', 'how', 'only', 'themselves', 'had', 'very', 'see', '’s', 'around', 'less', 'least', 'myself', 'together', 'nowhere', 'or', 'where', 'them', 'even', 'next', 'whence', 'with', 'other', "'d", 'any', 'ever', 'namely', 'moreover', 'former', 'indeed', 'amount', 'their', 'various', 'six', 'here', 'twelve', 'her', 'own', 'forty', 'yours', 'should', 'becoming', 'show', 'as', 'rather', 'make', 'under', 'three', 'herself', '’d', 'anyway', 'he', 'because', 'before', '‘m', 'nine', 'whereas', 'everywhere', 'your', 'whatever', 'seemed', '’ll', 'noone', 'which', 'yourselves', 'mine', 'two', 'is', 'beside', 'meanwhile', 'someone', 'such', 'not', 'being', 'could', 'keep', 'after', 'above', "n't", 'regarding', 'would', 'everyone', 'if', 'elsewhere', 'nobody', 'otherwise', 'does', 'none', 'ours', 'bottom', 'latter', 'due', "'ve", 'fifteen', 'no', 'what', 'therein', 'ten', 'somehow', 'about', 'so', 'within', 'across', 'one', 'neither', 'third', 'wherever', 'those', 'a', '‘ve', 'made', "'s", 'get', 'say', 'our', 'into', 'thence', 'whoever', 'doing', 'name', 'whose', 'hereupon', 'call', 'whereby', 'i', 'almost', 'upon', 'alone', 'anywhere', 'sometimes', 'by', 'hereby', 'who', 'was', "'re", 'via', 'several', 'in', 'but', 'somewhere', 'whenever', 'be', 'thereafter', 'per', 'last', 'another', 'thru', 'ca', 'n‘t', 'besides', 'his', 'whither', "'m", 'four', 'front', 'whereupon', 'something', 'put', 'although', 'can', 'formerly', 'more', 'well', 'ourselves', 'both', 'these', 'might', 'an', 'we', 'also', 'still', 'it', 'quite', 'herein', 'twenty', 'until', 'along', 'whereafter', 'than', 'am', 'really', 'too', 'using', 'yourself', 'hereafter', 'perhaps', '’m', 'though', 'onto', 'latterly', 'down', 'afterwards', 'hence', 'once', 'that', 'are', 'seems', 'himself', 'back', 'therefore', 'just', 'why', 'becomes', 'out', 'over', 'cannot', "'ll", 'must', 'much', 'give', 'on', 'some', 'enough', 'others', '‘ll', '‘d', 'of', 'seem', 'while', 'hundred', 'again', 'between', 'please', 'now', 'amongst', 'else', '’ve', 'whom', 'beyond', 'may', 'since', 'thus', 'anyhow', 'my', 'were', 'hers', 're', 'at', 'then', 'most', 'either', 'do', 'every', 'there', 'take', 'from', 'without', 'yet', 'among', 'been', 'everything'}

# %%
len(nlp.Defaults.stop_words)
# Out:
# 326

# %% [markdown]
# ## To see if a word is a stop word

# %%
nlp.vocab['than'].is_stop
# Out:
# True

# %%
nlp.vocab['btw'].is_stop
# Out:
# False

# %% [markdown]
# ## To add a stop word
# There may be times when you wish to add a stop word to the default set. Perhaps you decide that `'btw'` (common shorthand for "by the way") should be considered a stop word.

# %%
# Add the word to the set of stop words. Use lowercase!
nlp.Defaults.stop_words.add('btw')

# Set the stop_word tag on the lexeme
nlp.vocab['btw'].is_stop = True

# %%
nlp.vocab['btw'].is_stop
# Out:
# True

# %%
len(nlp.Defaults.stop_words)
# Out:
# 327

# %% [markdown]
# <font color=green>When adding stop words, always use lowercase. Lexemes are converted to lowercase before being added to **vocab**.</font>

# %% [markdown]
# ## To remove a stop word
# Alternatively, you may decide that `'beyond'` should not be considered a stop word.

# %%
# Remove the word from the set of stop words
nlp.Defaults.stop_words.remove('moreover')
nlp.Defaults.stop_words.remove('does')

# Remove the stop_word tag
nlp.vocab['does'].is_stop = False
nlp.vocab['moreover'].is_stop = False

# %%
nlp.vocab['does'].is_stop
# Out:
# False

# %%
len(nlp.Defaults.stop_words)
# Out:
# 325

# %%
nlp.vocab['moreover'].is_stop
# Out:
# False

# %%
nlp.Defaults.stop_words
# Out:
# {"'d",
#  "'ll",
#  "'m",
#  "'re",
#  "'s",
#  "'ve",
#  'a',
#  'about',
#  'above',
#  'across',
#  'after',
#  'afterwards',
#  'again',
#  'against',
#  'all',
#  'almost',
#  'alone',
#  'along',
#  'already',
#  'also',
#  'although',
#  'always',
#  'am',
#  'among',
#  'amongst',
#  'amount',
#  'an',
#  'and',
#  'another',
#  'any',
#  'anyhow',
#  'anyone',
#  'anything',
#  'anyway',
#  'anywhere',
#  'are',
#  'around',
#  'as',
#  'at',
#  'back',
#  'be',
#  'became',
#  'because',
#  'become',
#  'becomes',
#  'becoming',
#  'been',
#  'before',
#  'beforehand',
#  'behind',
#  'being',
#  'below',
#  'beside',
#  'besides',
#  'between',
#  'beyond',
#  'both',
#  'bottom',
#  'btw',
#  'but',
#  'by',
#  'ca',
#  'call',
#  'can',
#  'cannot',
#  'could',
#  'did',
#  'do',
#  'doing',
#  'done',
#  'down',
#  'due',
#  'during',
#  'each',
#  'eight',
#  'either',
#  'eleven',
#  'else',
#  'elsewhere',
#  'empty',
#  'enough',
#  'even',
#  'ever',
#  'every',
#  'everyone',
#  'everything',
#  'everywhere',
#  'except',
#  'few',
#  'fifteen',
#  'fifty',
#  'first',
#  'five',
#  'for',
#  'former',
#  'formerly',
#  'forty',
#  'four',
#  'from',
#  'front',
#  'full',
#  'further',
#  'get',
#  'give',
#  'go',
#  'had',
#  'has',
#  'have',
#  'he',
#  'hence',
#  'her',
#  'here',
#  'hereafter',
#  'hereby',
#  'herein',
#  'hereupon',
#  'hers',
#  'herself',
#  'him',
#  'himself',
#  'his',
#  'how',
#  'however',
#  'hundred',
#  'i',
#  'if',
#  'in',
#  'indeed',
#  'into',
#  'is',
#  'it',
#  'its',
#  'itself',
#  'just',
#  'keep',
#  'last',
#  'latter',
#  'latterly',
#  'least',
#  'less',
#  'made',
#  'make',
#  'many',
#  'may',
#  'me',
#  'meanwhile',
#  'might',
#  'mine',
#  'more',
#  'most',
#  'mostly',
#  'move',
#  'much',
#  'must',
#  'my',
#  'myself',
#  "n't",
#  'name',
#  'namely',
#  'neither',
#  'never',
#  'nevertheless',
#  'next',
#  'nine',
#  'no',
#  'nobody',
#  'none',
#  'noone',
#  'nor',
#  'not',
#  'nothing',
#  'now',
#  'nowhere',
#  'n‘t',
#  'n’t',
#  'of',
#  'off',
#  'often',
#  'on',
#  'once',
#  'one',
#  'only',
#  'onto',
#  'or',
#  'other',
#  'others',
#  'otherwise',
#  'our',
#  'ours',
#  'ourselves',
#  'out',
#  'over',
#  'own',
#  'part',
#  'per',
#  'perhaps',
#  'please',
#  'put',
#  'quite',
#  'rather',
#  're',
#  'really',
#  'regarding',
#  'same',
#  'say',
#  'see',
#  'seem',
#  'seemed',
#  'seeming',
#  'seems',
#  'serious',
#  'several',
#  'she',
#  'should',
#  'show',
#  'side',
#  'since',
#  'six',
#  'sixty',
#  'so',
#  'some',
#  'somehow',
#  'someone',
#  'something',
#  'sometime',
#  'sometimes',
#  'somewhere',
#  'still',
#  'such',
#  'take',
#  'ten',
#  'than',
#  'that',
#  'the',
#  'their',
#  'them',
#  'themselves',
#  'then',
#  'thence',
#  'there',
#  'thereafter',
#  'thereby',
#  'therefore',
#  'therein',
#  'thereupon',
#  'these',
#  'they',
#  'third',
#  'this',
#  'those',
#  'though',
#  'three',
#  'through',
#  'throughout',
#  'thru',
#  'thus',
#  'to',
#  'together',
#  'too',
#  'top',
#  'toward',
#  'towards',
#  'twelve',
#  'twenty',
#  'two',
#  'under',
#  'unless',
#  'until',
#  'up',
#  'upon',
#  'us',
#  'used',
#  'using',
#  'various',
#  'very',
#  'via',
#  'was',
#  'we',
#  'well',
#  'were',
#  'what',
#  'whatever',
#  'when',
#  'whence',
#  'whenever',
#  'where',
#  'whereafter',
#  'whereas',
#  'whereby',
#  'wherein',
#  'whereupon',
#  'wherever',
#  'whether',
#  'which',
#  'while',
#  'whither',
#  'who',
#  'whoever',
#  'whole',
#  'whom',
#  'whose',
#  'why',
#  'will',
#  'with',
#  'within',
#  'without',
#  'would',
#  'yet',
#  'you',
#  'your',
#  'yours',
#  'yourself',
#  'yourselves',
#  '‘d',
#  '‘ll',
#  '‘m',
#  '‘re',
#  '‘s',
#  '‘ve',
#  '’d',
#  '’ll',
#  '’m',
#  '’re',
#  '’s',
#  '’ve'}
