# %%
import pandas as pd

data = {
        'Valore': [10, 5, 8, 12, 3],
        'Quantità': [20, 15, 10, 25, 5],
        'Testo': ['abc', 'def', 'ghi', 'jkl', 'mno'],
        'Categoria': ['A', 'B', 'A', 'C', 'B'],
        'ID': [1, 2, 3, 4, 1],
        'Descrizione': ['desc1 importante', 'desc2', 'desc3', 'desc4 importante', 'desc5']
        }

df = pd.DataFrame(data)
df
# Out:
#    Valore  Quantità Testo Categoria  ID       Descrizione
# 0      10        20   abc         A   1  desc1 importante
# 1       5        15   def         B   2             desc2
# 2       8        10   ghi         A   3             desc3
# 3      12        25   jkl         C   4  desc4 importante
# 4       3         5   mno         B   1             desc5

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5 entries, 0 to 4
# Data columns (total 6 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Valore       5 non-null      int64
#  1   Quantità     5 non-null      int64
#  2   Testo        5 non-null      object
#  3   Categoria    5 non-null      object
#  4   ID           5 non-null      int64
#  5   Descrizione  5 non-null      object
# dtypes: int64(3), object(3)
# memory usage: 372.0+ bytes

# %%
## Creare una nuova colonna in un DataFrame chiamata "Doppio_Valore" che contenga il doppio del valore della colonna esistente "Valore".
df['Doppio_Valore'] = df['Valore'].apply(lambda x:2*x)
df
# Out:
#    Valore  Quantità Testo Categoria  ID       Descrizione  Doppio_Valore
# 0      10        20   abc         A   1  desc1 importante             20
# 1       5        15   def         B   2             desc2             10
# 2       8        10   ghi         A   3             desc3             16
# 3      12        25   jkl         C   4  desc4 importante             24
# 4       3         5   mno         B   1             desc5              6

# %%
#Filtrare le righe di un DataFrame in base a una condizione, ad esempio, ottenere solo le righe con valori superiori a 3 nella colonna "Valore".
# Out:
#    Valore  Doppio_Valore
# 3       4              8
# 4       5             10

# %%
#Applicare una lambda function alla colonna "Testo" per convertire tutti i valori in maiuscolo.
# Out:
#    Valore  Quantità Testo Categoria  ID       Descrizione
# 0      10        20   ABC         A   1  desc1 importante
# 1       5        15   DEF         B   2             desc2
# 2       8        10   GHI         A   3             desc3
# 3      12        25   JKL         C   4  desc4 importante
# 4       3         5   MNO         B   1             desc5

# %%
#Contare quante volte compare ciascun valore nella colonna "Categoria".
# Out:
#   Categoria  Conteggio
# 0         A          2
# 1         B          2
# 2         C          1

# %%
#Rinominare tutte le colonne di un DataFrame aggiungendo il prefisso "Nuovo_".
# Out:
#    Nuovo_Valore  Nuovo_Quantità Nuovo_Testo Nuovo_Categoria  Nuovo_ID  \
# 0            10              20         ABC               A         1
# 1             5              15         DEF               B         2
# 2             8              10         GHI               A         3
# 3            12              25         JKL               C         4
# 4             3               5         MNO               B         1
#
#   Nuovo_Descrizione
# 0  desc1 importante
# 1             desc2
# 2             desc3
# 3  desc4 importante
# 4             desc5

# %%
#Applicare una funzione a tutte le colonne:
# Out:
# Valore                                                      38
# Quantità                                                    75
# Testo                                          ABCDEFGHIJKLMNO
# Categoria                                                ABACB
# ID                                                          11
# Descrizione    desc1 importantedesc2desc3desc4 importantedesc5
# dtype: object

# %%
#Ordinare il DataFrame in base alla colonna "Valore" in ordine decrescente.
# Out:
#    Valore  Quantità Testo Categoria  ID       Descrizione
# 3      12        25   JKL         C   4  desc4 importante
# 0      10        20   ABC         A   1  desc1 importante
# 2       8        10   GHI         A   3             desc3
# 1       5        15   DEF         B   2             desc2
# 4       3         5   MNO         B   1             desc5

# %%
#Creare una nuova colonna "Totale" che rappresenti la somma di "Valore" e "Quantità".
# Out:
#    Valore  Quantità Testo Categoria  ID       Descrizione  Totale
# 0      10        20   ABC         A   1  desc1 importante      30
# 1       5        15   DEF         B   2             desc2      20
# 2       8        10   GHI         A   3             desc3      18
# 3      12        25   JKL         C   4  desc4 importante      37
# 4       3         5   MNO         B   1             desc5       8

# %%
#Rimuovere le righe duplicate basandosi sulla colonna "ID".
# Out:
#    Valore  Quantità Testo Categoria  ID       Descrizione  Totale
# 0      10        20   ABC         A   1  desc1 importante      30
# 1       5        15   DEF         B   2             desc2      20
# 2       8        10   GHI         A   3             desc3      18
# 3      12        25   JKL         C   4  desc4 importante      37

# %%
#Filtrare le righe del DataFrame in cui la colonna "Descrizione" contiene la parola "importante".
# Out:
#    Valore  Quantità Testo Categoria  ID       Descrizione  Totale
# 0      10        20   ABC         A   1  desc1 importante      30
# 3      12        25   JKL         C   4  desc4 importante      37
