# %% [markdown]
# ###  Crabs Dataset

# %% [markdown]
# <img src="https://frenzy86.s3.eu-west-2.amazonaws.com/IFAO/crab.jpg" width="750" align="center">

# %%
# !wget https://frenzy86.s3.eu-west-2.amazonaws.com/python/data/crabs.csv
# Out:
# --2024-05-23 19:50:32--  https://frenzy86.s3.eu-west-2.amazonaws.com/python/data/crabs.csv
# Resolving frenzy86.s3.eu-west-2.amazonaws.com (frenzy86.s3.eu-west-2.amazonaws.com)... 3.5.244.163, 52.95.148.166, 3.5.246.13, ...
# Connecting to frenzy86.s3.eu-west-2.amazonaws.com (frenzy86.s3.eu-west-2.amazonaws.com)|3.5.244.163|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 10189 (10.0K) [text/csv]
# Saving to: ‘crabs.csv’
#
# crabs.csv           100%[===================>]   9.95K  --.-KB/s    in 0s
#
# 2024-05-23 19:50:32 (122 MB/s) - ‘crabs.csv’ saved [10189/10189]
